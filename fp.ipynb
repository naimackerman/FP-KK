# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv('Placement_Data_Full_Class.csv')
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
df.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
plt.style.use('dark_background')
plt.figure(figsize=(10, 5))
sns.countplot('gender', data = df, palette='inferno')
plt.title("Distribusi gender Male dan Female di dalam dataset", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribusi gender Male dan Female di dalam dataset')

# %%
plt.figure(figsize=(10, 5))
sns.countplot('ssc_b', data = df, palette='inferno')
plt.title("Distribusi Boards Student dalam 10 tahun terakhir", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribusi Boards Student dalam 10 tahun terakhir')

# %%
plt.figure(figsize=(10, 5))
sns.countplot('hsc_b', data = df, palette='inferno')
plt.title("Distribusi Boards Student dalam 10 tahun terakhir", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribusi Boards Student dalam 10 tahun terakhir')

# %%
plt.figure(figsize=(10, 5))
sns.countplot('hsc_s', data = df, palette='inferno')
plt.title("Distribusi Streams yang dipilih pada saat High school", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribusi Streams yang dipilih pada saat High school')

# %%
plt.figure(figsize=(10, 5))
sns.countplot('degree_t', data = df, palette='inferno')
plt.title("Distribusi Tipe Degree", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribusi Tipe Degree')

# %%
plt.figure(figsize=(10, 5))
sns.countplot('workex', data = df, palette='inferno')
plt.title("Distribusi Student yang memiliki pengalaman kerja sebelumnya", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribusi Student yang memiliki pengalaman kerja sebelumnya')

# %%
plt.figure(figsize=(10, 5))
sns.countplot('specialisation', data = df, palette='inferno')
plt.title("Distribusi Tipe Spesialisasi", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribusi Tipe Spesialisasi')

# %%
plt.figure(figsize=(10, 5))
sns.countplot('status', data = df, palette='inferno')
plt.title("Distribusi Placements", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribusi Placements')

# %%
plt.figure(figsize=(10, 5))
sns.countplot('gender', data = df, palette='inferno', hue='status')
plt.title("Distribusi Placements pada gender Male dan Female", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribusi Placements pada gender Male dan Female')

# %%
plt.figure(figsize=(10, 5))
sns.countplot('workex', data = df, palette='inferno', hue='status')
plt.title("Distribusi Placements pada gender Male dan Female", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribusi Placements pada gender Male dan Female')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot('ssc_b', 'ssc_p', data = df, palette='inferno')
plt.title("Relasi antara Board Student dan scorenya ketika Sekolah Menengah", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Relasi antara Board Student dan scorenya ketika Sekolah Menengah')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot('status', 'ssc_p', data = df, palette='inferno')
plt.title("Relasi antara Student yang berstatus placed dan scorenya ketika Sekolah Menengah", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Relasi antara Student yang berstatus placed dan scorenya ketika Sekolah Menengah')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot('hsc_b', 'hsc_p', data = df, palette='inferno')
plt.title("Relasi antara Board Student dan scorenya pada saat High scool", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Relasi antara Board Student dan scorenya pada saat High scool')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot('status', 'hsc_p', data = df, palette='inferno')
plt.title("Relasi antara Student berstatus placed dan scorenya pada saat High scool", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Relasi antara Student berstatus placed dan scorenya pada saat High scool')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot('status', 'mba_p', data = df, palette='inferno')
plt.title("Relasi antara Student berstatus placed dan scorenya ketika MBA", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Relasi antara Student berstatus placed dan scorenya ketika MBA')

# %%
plt.figure(figsize=(10, 5))
sns.countplot('ssc_b', data = df, palette='inferno', hue='status')
plt.title("Relasi antara Student berstatus placed dan board yang mereka tempati ketika Sekolah Menengah", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Relasi antara Student berstatus placed dan board yang mereka tempati ketika Sekolah Menengah')

# %%
plt.figure(figsize=(10, 5))
sns.countplot('hsc_b', data = df, palette='inferno', hue='status')
plt.title("Relasi antara Student berstatus placed dan board yang mereka tempati ketika High School", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Relasi antara Student berstatus placed dan board yang mereka tempati ketika High School')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot('status', 'degree_p', data = df, palette='inferno')
plt.title("Relasi antara Student berstatus placed dan persentase degreenya", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Relasi antara Student berstatus placed dan persentase degreenya')

# %%
plt.figure(figsize=(10, 5))
sns.countplot('hsc_s', data = df, palette='inferno', hue='status')
plt.title("Relasi antara streams yang dipilih ketika highschool dan placementnya", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Relasi antara streams yang dipilih ketika highschool dan placementnya')

# %%
plt.figure(figsize=(10, 5))
sns.countplot('degree_t', data = df, palette='inferno', hue='status')
plt.title("Relasi antara tipe degree yang dipilih dan placementnya", fontsize=15)
# Out:
# E:\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Relasi antara tipe degree yang dipilih dan placementnya')

# %%
df1 = df.copy()

# %%
df1.drop(['sl_no', 'salary'], axis=1, inplace=True)
df1.head()
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p      status
# 0     No     55.0         Mkt&HR  58.80      Placed
# 1    Yes     86.5        Mkt&Fin  66.28      Placed
# 2     No     75.0        Mkt&Fin  57.80      Placed
# 3     No     66.0         Mkt&HR  59.43  Not Placed
# 4     No     96.8        Mkt&Fin  55.50      Placed

# %%
df1['status'] = df1['status'].map({'Placed' : 1, 'Not Placed' : 0})
df1['workex'] = df1['workex'].map({'Yes' : 1, 'No' : 0})
df1['gender'] = df1['gender'].map({'M' : 1, 'F' : 0})
df1['hsc_b'] = df1['hsc_b'].map({'Central' : 1, 'Others' : 0})
df1['ssc_b'] = df1['ssc_b'].map({'Central' : 1, 'Others' : 0})
df1['degree_t'] = df1['degree_t'].map({'Sci&Tech' : 0, 'Comm&Mgmt' : 1, 'Others' : 2})
df1['specialisation'] = df1['specialisation'].map({'Mkt&HR' : 1, 'Mkt&Fin' : 0})
df1['hsc_s'] = df1['hsc_s'].map({'Commerce' : 0, 'Science' : 1, 'Arts' : 2})

df1.head()
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0       1  67.00      0  91.00      0      0     58.00         0       0
# 1       1  79.33      1  78.33      0      1     77.48         0       1
# 2       1  65.00      1  68.00      1      2     64.00         1       0
# 3       1  56.00      1  52.00      1      1     52.00         0       0
# 4       1  85.80      1  73.60      1      0     73.30         1       0
#
#    etest_p  specialisation  mba_p  status
# 0     55.0               1  58.80       1
# 1     86.5               0  66.28       1
# 2     75.0               0  57.80       1
# 3     66.0               1  59.43       0
# 4     96.8               0  55.50       1

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, recall_score, precision_score

# %%
X = df1[['ssc_p', 'hsc_p', 'degree_p', 'workex', 'mba_p', 'etest_p', 'gender', 'degree_t', 'specialisation']]
y = df1['status']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
pred = lr.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, pred) * 100)
print("Precision:", precision_score(y_test, pred) * 100)
print("Recall:", recall_score(y_test, pred) * 100)
# Out:
# Accuracy: 88.37209302325581
# Precision: 89.28571428571429
# Recall: 92.5925925925926

# %%
user_input1 = [[67.00, 91.00, 58.00, 0, 58.80, 55.00, 1, 0, 1]]
user_pred1 = lr.predict(user_input1)
if user_pred1 == 1:
    print("The Candidate will be Placed!")
else:
    print("The Candidate won't be Placed :(")
# Out:
# The Candidate will be Placed!

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
prediction = knn.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, prediction) * 100)
print("Precision:", precision_score(y_test, prediction) * 100)
print("Recall:", recall_score(y_test, prediction) * 100)
# Out:
# Accuracy: 74.4186046511628
# Precision: 80.76923076923077
# Recall: 77.77777777777779

# %%
user_input2 = [[67.00, 91.00, 58.00, 0, 58.80, 55.00, 1, 0, 1]]
user_pred2 = knn.predict(user_input2)
if user_pred1 == 1:
    print("The Candidate will be Placed!")
else:
    print("The Candidate won't be Placed :(")
# Out:
# The Candidate will be Placed!

# %%
error = []
for i in  range(1,100):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1, 100), error)
plt.title('K-values')
plt.xlabel('K')
plt.ylabel('Error')
# Out:
# Text(0, 0.5, 'Error')

# %%
knn1 = KNeighborsClassifier(n_neighbors=20)
knn1.fit(X_train, y_train)
prediction1 = knn1.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, prediction1) * 100)
print("Precision:", precision_score(y_test, prediction1) * 100)
print("Recall:", recall_score(y_test, prediction1) * 100)
# Out:
# Accuracy: 86.04651162790698
# Precision: 83.87096774193549
# Recall: 96.29629629629629

# %%
user_input3 = [[67.00, 91.00, 58.00, 0, 58.80, 55.00, 1, 0, 1]]
user_pred3 = knn1.predict(user_input1)
if user_pred3 == 1:
    print("The Candidate will be Placed!")
else:
    print("The Candidate won't be Placed :(")
# Out:
# The Candidate will be Placed!

# %%
from sklearn.svm import SVC

# %%
svc = SVC()
svc.fit(X_train, y_train)
svc_pred = svc.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test

# [CV 1/5] END ..................C=100, gamma=0.1;, score=0.829 total time=   0.0s
# [CV 2/5] END ..................C=100, gamma=0.1;, score=0.771 total time=   0.0s
# [CV 3/5] END ..................C=100, gamma=0.1;, score=0.647 total time=   0.0s
# [CV 4/5] END ..................C=100, gamma=0.1;, score=0.706 total time=   0.0s
# [CV 5/5] END ..................C=100, gamma=0.1;, score=0.794 total time=   0.0s
# [CV 1/5] END .................C=100, gamma=0.01;, score=0.886 total time=   0.0s
# [CV 2/5] END .................C=100, gamma=0.01;, score=0.857 total time=   0.0s
# [CV 3/5] END .................C=100, gamma=0.01;, score=0.882 total time=   0.0s
# [CV 4/5] END .................C=100, gamma=0.01;, score=0.853 total time=   0.0s
# [CV 5/5] END .................C=100, gamma=0.01;, score=0.882 total time=   0.0s
# [CV 1/5] END ................C=100, gamma=0.001;, score=0.886 total time=   0.0s
# [CV 2/5] END ................C=100, gamma=0.001;, score=0.829 total time=   0.0s
# [CV 3/5] END ................C=100, gamma=0.001;, score=0.882 total time=   0.0s
# [CV 4/5] END ................C=100, gamma=0.001;, score=0.912 total time=   0.0s
# [CV 5/5] END ................C=100, gamma=0.001;, score=0.941 total time=   0.0s
# [CV 1/5] END ...............C=100, gamma=0.0001;, score=0.886 total time=   0.0s
# [CV 2/5] END ...............C=100, gamma=0.0001;, score=0.771 total time=   0.0s
# [CV 3/5] END ...............C=100, gamma=0.0001;, score=0.853 total time=   0.0s
# [CV 4/5] END ...............C=100, gamma=0.0001;, score=0.794 total time=   0.0s
# [CV 5/5] END ...............C=100, gamma=0.0001;, score=0.882 total time=   0.0s
# [CV 1/5] END ...................C=1000, gamma=1;, score=0.714 total time=   0.0s
# [CV 2/5] END ...................C=1000, gamma=1;, score=0.657 total time=   0.0s
# [CV 3/5] END ...................C=1000, gamma=1;, score=0.706 total time=   0.0s
# [CV 4/5] END ...................C=1000, gamma=1;, score=0.676 total time=   0.0s
# [CV 5/5] END ...................C=1000, gamma=1;, score=0.706 total time=   0.0s
# [CV 1/5] END .................C=1000, gamma=0.1;, score=0.800 total time=   0.0s
# [CV 2/5] END .................C=1000, gamma=0.1;, score=0.771 total time=   0.0s
# [CV 3/5] END .................C=1000, gamma=0.1;, score=0.647 total time=   0.0s
# [CV 4/5] END .................C=1000, gamma=0.1;, score=0.706 total time=   0.0s
# [CV 5/5] END .................C=1000, gamma=0.1;, score=0.794 total time=   0.0s
# [CV 1/5] END ................C=1000, gamma=0.01;, score=0.857 total time=   0.0s
# [CV 2/5] END ................C=1000, gamma=0.01;, score=0.886 total time=   0.0s
# [CV 3/5] END ................C=1000, gamma=0.01;, score=0.735 total time=   0.0s
# [CV 4/5] END ................C=1000, gamma=0.01;, score=0.706 total time=   0.0s
# [CV 5/5] END ................C=1000, gamma=0.01;, score=0.824 total time=   0.0s
# [CV 1/5] END ...............C=1000, gamma=0.001;, score=0.886 total time=   0.0s
# [CV 2/5] END ...............C=1000, gamma=0.001;, score=0.857 total time=   0.0s
# [CV 3/5] END ...............C=1000, gamma=0.001;, score=0.882 total time=   0.0s
# [CV 4/5] END ...............C=1000, gamma=0.001;, score=0.912 total time=   0.0s
# [CV 5/5] END ...............C=1000, gamma=0.001;, score=0.882 total time=   0.0s
# [CV 1/5] END ..............C=1000, gamma=0.0001;, score=0.886 total time=   0.0s
# [CV 2/5] END ..............C=1000, gamma=0.0001;, score=0.829 total time=   0.0s
# [CV 3/5] END ..............C=1000, gamma=0.0001;, score=0.882 total time=   0.0s
# [CV 4/5] END ..............C=1000, gamma=0.0001;, score=0.912 total time=   0.0s
# [CV 5/5] END ..............C=1000, gamma=0.0001;, score=0.941 total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001]},
#              verbose=3)

# %%
grid.best_estimator_
# Out:
# SVC(C=100, gamma=0.001)

# %%
grid.best_params_
# Out:
# {'C': 100, 'gamma': 0.001}

# %%
grid_pred = grid.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, grid_pred) * 100)
print("Precision:", precision_score(y_test, grid_pred) * 100)
print("Recall:", recall_score(y_test, grid_pred) * 100)
# Out:
# Accuracy: 83.72093023255815
# Precision: 85.71428571428571
# Recall: 88.88888888888889

# %%
user_input4 = [[56.00, 52.00, 52.00, 0, 59.43, 66.00, 1, 0, 1]]
user_pred4 = grid.predict(user_input4)
if user_pred4 == 1:
    print("The Candidate will be Placed!")
else:
    print("The Candidate won't be Placed :(")
# Out:
# The Candidate won't be Placed :(
